# %%
from perceptron import Perceptron
import numpy as np

data = np.fromfile('../data/dataAll.txt')
data = data.reshape(data.shape[0]//3, 3)

X = data[:,:-1]
Y = data[:,-1]

# %%
from perceptron import Perceptron
import numpy as np

data = np.fromfile('../data/dataAll.txt')
data = data.reshape(data.shape[0]//3, 3)

X = data[:,:-1]
Y = data[:,-1]

# %%
p = Perceptron()
p.fit(X, Y)
# Out:
# Pesos iniciais: [ 0.19888478  0.47848789 -0.12943261]
# ------ Época 1 ------
# Novos pesos: [  0.29888478 -53.18056211 -76.62518261]
# Novos pesos: [  0.19888478  19.61545789 -40.79562261]
# Novos pesos: [9.88847768e-02 1.02214158e+02 3.90602074e+01]
# Novos pesos: [  0.19888478 108.05991789 -39.23438261]
# Novos pesos: [   0.29888478   68.05100789 -117.12707261]
# Novos pesos: [  0.39888478 126.49392789 -75.54679261]
# Novos pesos: [   0.29888478   73.53386789 -132.41625261]
# Novos pesos: [  0.39888478 133.09338789 -82.29392261]
# Novos pesos: [   0.29888478   87.56875789 -147.92985261]
# Novos pesos: [   0.39888478  101.90718789 -138.54363261]
# Novos pesos: [  0.49888478 192.62304789 -63.83031261]
# Novos pesos: [   0.39888478  134.84205789 -124.13846261]
# Novos pesos: [   0.29888478   84.93223789 -175.39889261]
# Novos pesos: [   0.19888478  112.75596789 -157.34397261]
# Novos pesos: [ 9.88847768e-02  1.40219558e+02 -1.36487623e+02]
# Novos pesos: [-1.11522324e-03  7.13638779e+01 -2.06557923e+02]
# Novos pesos: [ 9.88847768e-02  1.02814268e+02 -1.82126523e+02]
# Novos pesos: [-1.11522324e-03  1.65711578e+02 -1.23939563e+02]
# Novos pesos: [ 9.88847768e-02  1.16594448e+02 -1.75788463e+02]
# Novos pesos: [-1.11522324e-03  1.83074358e+02 -1.23782623e+02]
# Novos pesos: [ 9.88847768e-02  1.29920298e+02 -1.97698543e+02]
# Novos pesos: [ 1.98884777e-01  2.26299928e+02 -1.19600643e+02]
# Novos pesos: [ 9.88847768e-02  1.28888488e+02 -2.18771853e+02]
# Novos pesos: [-1.11522324e-03  2.22674078e+02 -1.50277983e+02]
# Novos pesos: [ 9.88847768e-02  1.52049558e+02 -2.34423673e+02]
# Novos pesos: [-1.11522324e-03  2.36407988e+02 -1.72610943e+02]
# Novos pesos: [-1.01115223e-01  1.76715738e+02 -2.34815433e+02]
# Novos pesos: [-1.11522324e-03  2.41670498e+02 -1.71593283e+02]
# Novos pesos: [ 9.88847768e-02  1.60009188e+02 -2.54470663e+02]
# Novos pesos: [-1.11522324e-03  2.29872818e+02 -1.90251723e+02]
# Novos pesos: [ 9.88847768e-02  1.74037088e+02 -2.46429253e+02]
# Novos pesos: [-1.11522324e-03  2.51024558e+02 -1.81579923e+02]
# Novos pesos: [-1.01115223e-01  2.14754518e+02 -2.24807963e+02]
# Novos pesos: [-2.01115223e-01  2.97646388e+02 -1.42026473e+02]
# Novos pesos: [  -0.30111522  251.49900789 -198.67585261]
# Novos pesos: [-2.01115223e-01  2.24873388e+02 -2.31198223e+02]
# Novos pesos: [  -0.30111522  271.89774789 -184.64405261]
# Novos pesos: [  -0.40111522  242.01368789 -217.75338261]
# Novos pesos: [  -0.30111522  223.77454789 -236.08702261]
# Novos pesos: [-2.01115223e-01  2.55081428e+02 -2.05458703e+02]
# Novos pesos: [-1.01115223e-01  1.79527528e+02 -2.82781653e+02]
# Novos pesos: [-1.11522324e-03  2.48503418e+02 -2.17990723e+02]
# Novos pesos: [ 9.88847768e-02  1.52691868e+02 -3.15872463e+02]
# Novos pesos: [-1.11522324e-03  2.33865598e+02 -2.64524523e+02]
# Novos pesos: [ 9.88847768e-02  3.33333428e+02 -1.72634963e+02]
# Novos pesos: [-1.11522324e-03  2.74628508e+02 -2.64972213e+02]
# Novos pesos: [ 9.88847768e-02  2.30770378e+02 -3.09511223e+02]
# Novos pesos: [-1.11522324e-03  3.18013488e+02 -2.42599303e+02]
# Total de ajustes: 48
# ------ Época 2 ------
# Novos pesos: [ 9.88847768e-02  2.86590518e+02 -2.76983053e+02]
# Novos pesos: [-1.11522324e-03  2.36680698e+02 -3.28243483e+02]
# Novos pesos: [-1.01115223e-01  2.64144288e+02 -3.07387133e+02]
# Novos pesos: [-1.11522324e-03  3.13605108e+02 -2.58493083e+02]
# Novos pesos: [ 9.88847768e-02  2.85397648e+02 -2.92077203e+02]
# Novos pesos: [ 1.98884777e-01  3.72532408e+02 -2.05387373e+02]
# Novos pesos: [ 2.98884777e-01  3.20617078e+02 -2.61588393e+02]
# Novos pesos: [   0.39888478  255.73104789 -336.20448261]
# Novos pesos: [ 2.98884777e-01  3.45439848e+02 -2.57195763e+02]
# Novos pesos: [ 1.98884777e-01  2.67976898e+02 -3.55183473e+02]
# Novos pesos: [ 9.88847768e-02  3.12882238e+02 -3.11779533e+02]
# Total de ajustes: 11
# ------ Época 3 ------
# Total de ajustes: 0
# *********************
# Total de épocas: 3
# Total de ajustes de peso: 59

# %%
p = Perceptron()
p.fit(X, Y)
# Out:
# Pesos iniciais: [-0.0656638   0.41078627  0.32982756]
# ------ Época 1 ------
# Novos pesos: [ 3.43362042e-02  1.69090563e+01 -6.09918124e+01]
# Novos pesos: [-6.56637958e-02  8.97050763e+01 -2.51622524e+01]
# Novos pesos: [ 3.43362042e-02  6.17546627e+00 -1.24288082e+02]
# Novos pesos: [   0.1343362    55.36232627 -107.65935244]
# Novos pesos: [ 3.43362042e-02  1.37961026e+02 -2.78035224e+01]
# Novos pesos: [   0.1343362    97.95211627 -105.69621244]
# Novos pesos: [  0.2343362  147.41293627 -56.80216244]
# Novos pesos: [   0.3343362   107.86368627 -153.89620244]
# Novos pesos: [  0.4343362  200.10566627 -67.42363244]
# Novos pesos: [  0.5343362  188.20855627 -95.32317244]
# Novos pesos: [   0.6343362   160.00109627 -128.90729244]
# Novos pesos: [   0.5343362    95.71188627 -196.97192244]
# Novos pesos: [   0.4343362   148.81620627 -161.19252244]
# Novos pesos: [   0.5343362   213.80736627 -100.30084244]
# Novos pesos: [   0.4343362   162.87378627 -163.70081244]
# Novos pesos: [  0.3343362  245.76565627 -80.91932244]
# Novos pesos: [   0.2343362   199.61827627 -137.56870244]
# Novos pesos: [   0.3343362   135.70480627 -221.94312244]
# Novos pesos: [   0.2343362   180.29708627 -190.22808244]
# Novos pesos: [ 1.34336204e-01  2.27321446e+02 -1.43673912e+02]
# Novos pesos: [ 3.43362042e-02  1.97437386e+02 -1.76783242e+02]
# Novos pesos: [ 1.34336204e-01  1.79198246e+02 -1.95116882e+02]
# Novos pesos: [   0.2343362   210.50512627 -164.48856244]
# Novos pesos: [ 1.34336204e-01  1.36420326e+02 -2.59169792e+02]
# Novos pesos: [   0.2343362   187.09129627 -220.83832244]
# Novos pesos: [   0.3343362   278.39950627 -137.56755244]
# Novos pesos: [   0.2343362   231.35467627 -225.47149244]
# Novos pesos: [   0.3343362   155.80077627 -302.79444244]
# Novos pesos: [   0.4343362   224.77666627 -238.00351244]
# Novos pesos: [   0.3343362   267.24666627 -197.82486244]
# Novos pesos: [   0.4343362   171.43511627 -295.70660244]
# Novos pesos: [   0.3343362   252.60884627 -244.35866244]
# Novos pesos: [   0.4343362   208.75071627 -288.89767244]
# Novos pesos: [   0.3343362   295.99382627 -221.98575244]
# Total de ajustes: 34
# ------ Época 2 ------
# Novos pesos: [   0.4343362   264.57085627 -256.36950244]
# Novos pesos: [   0.3343362   214.66103627 -307.62993244]
# Novos pesos: [ 2.34336204e-01  2.42124626e+02 -2.86773582e+02]
# Novos pesos: [   0.3343362   291.58544627 -237.87953244]
# Novos pesos: [   0.4343362   263.37798627 -271.46365244]
# Novos pesos: [   0.5343362   350.51274627 -184.77382244]
# Novos pesos: [   0.6343362   298.59741627 -240.97484244]
# Novos pesos: [   0.7343362   233.71138627 -315.59093244]
# Novos pesos: [   0.6343362   300.74903627 -265.42443244]
# Novos pesos: [   0.5343362   234.07420627 -335.31976244]
# Novos pesos: [   0.6343362   265.52459627 -310.88836244]
# Novos pesos: [   0.5343362   328.42190627 -252.70140244]
# Novos pesos: [   0.6343362   279.30477627 -304.55030244]
# Novos pesos: [   0.5343362   341.79481627 -245.40623244]
# Novos pesos: [   0.6343362   288.64075627 -319.32215244]
# Novos pesos: [   0.7343362   353.59551627 -256.10000244]
# Novos pesos: [   0.8343362   271.93420627 -338.97738244]
# Novos pesos: [   0.7343362   341.79783627 -274.75844244]
# Novos pesos: [   0.8343362   285.96210627 -330.93597244]
# Novos pesos: [   0.7343362   368.85397627 -248.15448244]
# Novos pesos: [   0.6343362   322.70659627 -304.80386244]
# Novos pesos: [   0.7343362   304.46745627 -323.13750244]
# Novos pesos: [   0.8343362   335.77433627 -292.50918244]
# Novos pesos: [   0.9343362   260.22043627 -369.83213244]
# Novos pesos: [   1.0343362   329.19632627 -305.04120244]
# Novos pesos: [   1.1343362   233.38477627 -402.92294244]
# Novos pesos: [   1.0343362   314.55850627 -351.57500244]
# Novos pesos: [   1.1343362   414.02633627 -259.68544244]
# Novos pesos: [   1.0343362   355.32141627 -352.02269244]
# Total de ajustes: 29
# ------ Época 3 ------
# Novos pesos: [   0.9343362   307.05485627 -400.49241244]
# Novos pesos: [   0.8343362   376.91848627 -336.27347244]
# Novos pesos: [   0.9343362   321.08275627 -392.45100244]
# Novos pesos: [   0.8343362   398.07022627 -327.60167244]
# Novos pesos: [   0.7343362   361.80018627 -370.82971244]
# Novos pesos: [   0.6343362   444.69205627 -288.04822244]
# Novos pesos: [   0.5343362   398.54467627 -344.69760244]
# Novos pesos: [   0.4343362   368.66061627 -377.80693244]
# Novos pesos: [   0.5343362   399.96749627 -347.17861244]
# Novos pesos: [   0.6343362   324.41359627 -424.50156244]
# Novos pesos: [   0.7343362   393.38948627 -359.71063244]
# Novos pesos: [   0.8343362   297.57793627 -457.59237244]
# Novos pesos: [   0.9343362   397.04576627 -365.70281244]
# Novos pesos: [   1.0343362   353.18763627 -410.24182244]
# Total de ajustes: 14
# ------ Época 4 ------
# Novos pesos: [   0.9343362   435.78633627 -330.38599244]
# Novos pesos: [   0.8343362   382.82627627 -387.25545244]
# Novos pesos: [   0.9343362   469.96103627 -300.56562244]
# Novos pesos: [   1.0343362   418.04570627 -356.76664244]
# Novos pesos: [   1.1343362   353.15967627 -431.38273244]
# Novos pesos: [   1.0343362   442.86847627 -352.37401244]
# Novos pesos: [   0.9343362   376.19364627 -422.26934244]
# Novos pesos: [   0.8343362   439.09095627 -364.08238244]
# Novos pesos: [   0.9343362   389.97382627 -415.93128244]
# Novos pesos: [   0.8343362   452.46386627 -356.78721244]
# Novos pesos: [   0.7343362   355.05242627 -455.95842244]
# Novos pesos: [   0.8343362   420.00718627 -392.73627244]
# Novos pesos: [   0.9343362   338.34587627 -475.61365244]
# Novos pesos: [   0.8343362   408.20950627 -411.39471244]
# Novos pesos: [   0.7343362   491.10137627 -328.61322244]
# Novos pesos: [   0.6343362   444.95399627 -385.26260244]
# Novos pesos: [   0.5343362   415.06993627 -418.37193244]
# Total de ajustes: 17
# ------ Época 5 ------
# Novos pesos: [   0.6343362   502.20469627 -331.68210244]
# Novos pesos: [   0.7343362   450.28936627 -387.88312244]
# Novos pesos: [   0.8343362   385.40333627 -462.49921244]
# Novos pesos: [   0.7343362   475.11213627 -383.49049244]
# Novos pesos: [   0.6343362   408.43730627 -453.38582244]
# Novos pesos: [   0.5343362   471.33461627 -395.19886244]
# Novos pesos: [   0.6343362   422.21748627 -447.04776244]
# Novos pesos: [   0.5343362   484.70752627 -387.90369244]
# Novos pesos: [ 4.34336204e-01  3.87296086e+02 -4.87074902e+02]
# Novos pesos: [   0.5343362   452.25084627 -423.85275244]
# Novos pesos: [   0.6343362   370.58953627 -506.73013244]
# Novos pesos: [   0.5343362   440.45316627 -442.51119244]
# Novos pesos: [ 4.34336204e-01  5.23345036e+02 -3.59729702e+02]
# Novos pesos: [ 3.34336204e-01  4.77197656e+02 -4.16379082e+02]
# Novos pesos: [ 2.34336204e-01  4.47313596e+02 -4.49488412e+02]
# Total de ajustes: 15
# ------ Época 6 ------
# Novos pesos: [ 1.34336204e-01  5.30205466e+02 -3.66706922e+02]
# Novos pesos: [ 3.43362042e-02  4.84058086e+02 -4.23356302e+02]
# Novos pesos: [-6.56637958e-02  4.54174026e+02 -4.56465632e+02]
# Total de ajustes: 3
# ------ Época 7 ------
# Novos pesos: [-1.65663796e-01  5.37065896e+02 -3.73684142e+02]
# Novos pesos: [-2.65663796e-01  4.90918516e+02 -4.30333522e+02]
# Novos pesos: [-3.65663796e-01  4.61034456e+02 -4.63442852e+02]
# Total de ajustes: 3
# ------ Época 8 ------
# Novos pesos: [-2.65663796e-01  5.48169216e+02 -3.76753022e+02]
# Novos pesos: [-1.65663796e-01  4.96253886e+02 -4.32954042e+02]
# Novos pesos: [-2.65663796e-01  4.13761136e+02 -5.23688492e+02]
# Novos pesos: [-3.65663796e-01  5.03469936e+02 -4.44679772e+02]
# Novos pesos: [-4.65663796e-01  4.36795106e+02 -5.14575102e+02]
# Novos pesos: [  -0.5656638   499.69241627 -456.38814244]
# Novos pesos: [-4.65663796e-01  4.50575286e+02 -5.08237042e+02]
# Novos pesos: [  -0.5656638   542.49355627 -425.92193244]
# Novos pesos: [  -0.6656638   445.08211627 -525.09314244]
# Novos pesos: [  -0.5656638   510.03687627 -461.87099244]
# Novos pesos: [-4.65663796e-01  4.28375566e+02 -5.44748372e+02]
# Novos pesos: [  -0.5656638   498.23919627 -480.52943244]
# Novos pesos: [-4.65663796e-01  4.42403466e+02 -5.36706962e+02]
# Novos pesos: [  -0.5656638   519.39093627 -471.85763244]
# Novos pesos: [  -0.6656638   464.09219627 -529.88497244]
# Novos pesos: [  -0.7656638   546.98406627 -447.10348244]
# Novos pesos: [  -0.6656638   520.35844627 -479.62585244]
# Novos pesos: [  -0.5656638   502.11930627 -497.95949244]
# Total de ajustes: 18
# ------ Época 9 ------
# Novos pesos: [  -0.6656638   453.85274627 -546.42921244]
# Novos pesos: [  -0.7656638   523.71637627 -482.21027244]
# Novos pesos: [  -0.6656638   467.88064627 -538.38780244]
# Novos pesos: [  -0.7656638   550.77251627 -455.60631244]
# Novos pesos: [  -0.8656638   520.88845627 -488.71564244]
# Novos pesos: [  -0.7656638   502.64931627 -507.04928244]
# Total de ajustes: 6
# ------ Época 10 ------
# Novos pesos: [  -0.6656638   589.78407627 -420.35945244]
# Novos pesos: [  -0.5656638   537.86874627 -476.56047244]
# Novos pesos: [  -0.6656638   455.37599627 -567.29492244]
# Novos pesos: [  -0.7656638   545.08479627 -488.28620244]
# Novos pesos: [  -0.8656638   478.40996627 -558.18153244]
# Novos pesos: [  -0.9656638   541.30727627 -499.99457244]
# Novos pesos: [  -0.8656638   492.19014627 -551.84347244]
# Novos pesos: [  -0.9656638   584.10841627 -469.52836244]
# Novos pesos: [  -1.0656638   486.69697627 -568.69957244]
# Novos pesos: [  -0.9656638   551.65173627 -505.47742244]
# Novos pesos: [  -0.8656638   469.99042627 -588.35480244]
# Novos pesos: [  -0.9656638   539.85405627 -524.13586244]
# Novos pesos: [  -0.8656638   484.01832627 -580.31339244]
# Novos pesos: [  -0.9656638   561.00579627 -515.46406244]
# Novos pesos: [  -1.0656638   505.70705627 -573.49140244]
# Novos pesos: [  -1.1656638   588.59892627 -490.70991244]
# Novos pesos: [  -1.2656638   558.71486627 -523.81924244]
# Novos pesos: [  -1.1656638   540.47572627 -542.15288244]
# Total de ajustes: 18
# ------ Época 11 ------
# Novos pesos: [  -1.2656638   623.36759627 -459.37139244]
# Novos pesos: [  -1.3656638   577.22021627 -516.02077244]
# Novos pesos: [  -1.4656638   547.33615627 -549.13010244]
# Total de ajustes: 3
# ------ Época 12 ------
# Novos pesos: [  -1.5656638   630.22802627 -466.34861244]
# Novos pesos: [  -1.6656638   584.08064627 -522.99799244]
# Novos pesos: [  -1.7656638   554.19658627 -556.10732244]
# Total de ajustes: 3
# ------ Época 13 ------
# Novos pesos: [  -1.8656638   637.08845627 -473.32583244]
# Novos pesos: [  -1.9656638   590.94107627 -529.97521244]
# Novos pesos: [  -2.0656638   561.05701627 -563.08454244]
# Total de ajustes: 3
# ------ Época 14 ------
# Novos pesos: [  -2.1656638   643.94888627 -480.30305244]
# Novos pesos: [  -2.2656638   597.80150627 -536.95243244]
# Novos pesos: [  -2.3656638   567.91744627 -570.06176244]
# Total de ajustes: 3
# ------ Época 15 ------
# Novos pesos: [  -2.4656638   650.80931627 -487.28027244]
# Novos pesos: [  -2.5656638   604.66193627 -543.92965244]
# Novos pesos: [  -2.6656638   574.77787627 -577.03898244]
# Total de ajustes: 3
# ------ Época 16 ------
# Novos pesos: [  -2.7656638   657.66974627 -494.25749244]
# Novos pesos: [  -2.8656638   611.52236627 -550.90687244]
# Novos pesos: [  -2.9656638   581.63830627 -584.01620244]
# Total de ajustes: 3
# ------ Época 17 ------
# Novos pesos: [  -3.0656638   664.53017627 -501.23471244]
# Novos pesos: [  -3.1656638   618.38279627 -557.88409244]
# Novos pesos: [  -3.2656638   588.49873627 -590.99342244]
# Total de ajustes: 3
# ------ Época 18 ------
# Novos pesos: [  -3.3656638   671.39060627 -508.21193244]
# Novos pesos: [  -3.4656638   625.24322627 -564.86131244]
# Novos pesos: [  -3.3656638   607.00408627 -583.19495244]
# Novos pesos: [  -3.2656638   531.45018627 -660.51790244]
# Novos pesos: [  -3.1656638   600.42607627 -595.72697244]
# Total de ajustes: 5
# ------ Época 19 ------
# Novos pesos: [  -3.2656638   552.15951627 -644.19669244]
# Novos pesos: [  -3.3656638   622.02314627 -579.97775244]
# Novos pesos: [  -3.2656638   566.18741627 -636.15528244]
# Novos pesos: [  -3.3656638   649.07928627 -553.37379244]
# Novos pesos: [  -3.4656638   619.19522627 -586.48312244]
# Novos pesos: [  -3.3656638   600.95608627 -604.81676244]
# Total de ajustes: 6
# ------ Época 20 ------
# Novos pesos: [  -3.2656638   688.09084627 -518.12693244]
# Novos pesos: [  -3.1656638   636.17551627 -574.32795244]
# Novos pesos: [  -3.2656638   553.68276627 -665.06240244]
# Novos pesos: [  -3.3656638   643.39156627 -586.05368244]
# Novos pesos: [  -3.4656638   576.71673627 -655.94901244]
# Novos pesos: [  -3.5656638   639.61404627 -597.76205244]
# Novos pesos: [  -3.4656638   590.49691627 -649.61095244]
# Novos pesos: [  -3.5656638   652.98695627 -590.46688244]
# Novos pesos: [  -3.6656638   555.57551627 -689.63809244]
# Novos pesos: [  -3.5656638   620.53027627 -626.41594244]
# Novos pesos: [  -3.6656638   703.42214627 -543.63445244]
# Novos pesos: [  -3.7656638   657.27476627 -600.28383244]
# Novos pesos: [  -3.6656638   639.03562627 -618.61747244]
# Novos pesos: [  -3.5656638   563.48172627 -695.94042244]
# Novos pesos: [  -3.4656638   632.45761627 -631.14949244]
# Total de ajustes: 15
# ------ Época 21 ------
# Total de ajustes: 0
# *********************
# Total de épocas: 21
# Total de ajustes de peso: 204
